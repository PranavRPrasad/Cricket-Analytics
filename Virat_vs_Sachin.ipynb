# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

# %%
df = pd.read_csv('ODI_data.csv')

# %%
df.head(2)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number Opposition         Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate
# ...

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '-', nan, '40', '6', '4', '87', '54', '46',
#        '30', '12', '69', '39', '14', '10', '9', '8', '7', '82', '52',
#        '41', '15', '98', '43', '19', '111', '48', '36', '25', '67', '60',
#        '84', '59', '55', '47', '85', '49', '45', '34', '29', '22', '74',
#        '28', '77', '50', '32', '23', '35', '122', '100', '95', '103',
#        '113', '53', '96', '27', '64', '58', '33', '31', '73', '56', '86',
#        '62', '106', '24', '57', '104', '26', '66', '51', '118', '105',
#        '101', '21', '79', '44', '102', '88', '80', '72', '97', '68', '89',
#        '38', '83', '63', '148', '166', '90', '76', '37', '70', '124',
#        '94', '140', '153', '107', '117', '121', '92', '78', '75', '114',
#        '115', '130', '128', '151', '110', '138', '135', '109', '61',
#        '179', '170', '112', '116', '91', '143', '93', '123', '145', '81',
# ...

# %%
df = df[df['Innings Runs Scored Num'] != '-']

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', nan, '40', '6', '4', '87', '54', '46', '30',
#        '12', '69', '39', '14', '10', '9', '8', '7', '82', '52', '41',
#        '15', '98', '43', '19', '111', '48', '36', '25', '67', '60', '84',
#        '59', '55', '47', '85', '49', '45', '34', '29', '22', '74', '28',
#        '77', '50', '32', '23', '35', '122', '100', '95', '103', '113',
#        '53', '96', '27', '64', '58', '33', '31', '73', '56', '86', '62',
#        '106', '24', '57', '104', '26', '66', '51', '118', '105', '101',
#        '21', '79', '44', '102', '88', '80', '72', '97', '68', '89', '38',
#        '83', '63', '148', '166', '90', '76', '37', '70', '124', '94',
#        '140', '153', '107', '117', '121', '92', '78', '75', '114', '115',
#        '130', '128', '151', '110', '138', '135', '109', '61', '179',
#        '170', '112', '116', '91', '143', '93', '123', '145', '81', '150',
# ...

# %%
df = df.dropna(subset = ['Innings Runs Scored Num'])

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '40', '6', '4', '87', '54', '46', '30', '12',
#        '69', '39', '14', '10', '9', '8', '7', '82', '52', '41', '15',
#        '98', '43', '19', '111', '48', '36', '25', '67', '60', '84', '59',
#        '55', '47', '85', '49', '45', '34', '29', '22', '74', '28', '77',
#        '50', '32', '23', '35', '122', '100', '95', '103', '113', '53',
#        '96', '27', '64', '58', '33', '31', '73', '56', '86', '62', '106',
#        '24', '57', '104', '26', '66', '51', '118', '105', '101', '21',
#        '79', '44', '102', '88', '80', '72', '97', '68', '89', '38', '83',
#        '63', '148', '166', '90', '76', '37', '70', '124', '94', '140',
#        '153', '107', '117', '121', '92', '78', '75', '114', '115', '130',
#        '128', '151', '110', '138', '135', '109', '61', '179', '170',
#        '112', '116', '91', '143', '93', '123', '145', '81', '150', '162',
# ...

# %%
df.dtypes
# Out:
# Innings Player                   object
# Innings Runs Scored              object
# Innings Runs Scored Num          object
# Innings Minutes Batted           object
# Innings Batted Flag              float64
# Innings Not Out Flag             float64
# Innings Balls Faced              object
# Innings Boundary Fours           object
# Innings Boundary Sixes           object
# Innings Batting Strike Rate      object
# Innings Number                   object
# Opposition                       object
# Ground                           object
# Innings Date                     object
# Country                          object
# 50's                             float64
# 100's                            float64
# Innings Runs Scored Buckets      object
# Innings Overs Bowled             object
# Innings Bowled Flag              float64
# Innings Maidens Bowled           object
# Innings Runs Conceded            object
# Innings Wickets Taken            object
# ...

# %%
df['Innings Date'] = pd.to_datetime(df['Innings Date'])

# %%
df['Year'] = df['Innings Date'].dt.year

# %%
df.head()
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number Opposition         Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  Year
# ...

# %%
df['Innings Runs Scored Num'] = df['Innings Runs Scored Num'].astype('int')
df['Innings Balls Faced'] = df['Innings Balls Faced'].astype('int')
df["50's"] = df["50's"].astype('int')
df["100's"] = df["100's"].astype('int')

# %%
df.dtypes
# Out:
# Innings Player                   object
# Innings Runs Scored              object
# Innings Runs Scored Num          int32
# Innings Minutes Batted           object
# Innings Batted Flag              float64
# Innings Not Out Flag             float64
# Innings Balls Faced              int32
# Innings Boundary Fours           object
# Innings Boundary Sixes           object
# Innings Batting Strike Rate      object
# Innings Number                   object
# Opposition                       object
# Ground                           object
# Innings Date                     datetime64[ns]
# Country                          object
# 50's                             int32
# 100's                            int32
# Innings Runs Scored Buckets      object
# Innings Overs Bowled             object
# Innings Bowled Flag              float64
# Innings Maidens Bowled           object
# Innings Runs Conceded            object
# Innings Wickets Taken            object
# ...

# %%
virat_df = df[(df.Year >= 2009) & (df.Year <= 2019)]
sachin_df = df[(df.Year >= 1994) & (df.Year <= 2004)]

# %%
virat_df.tail(2)
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number     Opposition        Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  Year
# ...

# %%
sachin_df['Year'].head(2)
# Out:
# 77610    2004
# 77611    2004
# Name: Year, dtype: int64

# %%
sachin_df['Year'].tail(2)
# Out:
# 133838    1994
# 133839    1994
# Name: Year, dtype: int64

# %%
# Runs per innings = Total Runs/Total Innings
# SR = 100*(Total Runs/Total Balls)
# 100's = sum(100's)
# 50's = sum(50's)
# Team contribution = Player Runs/Team Runs (ex: Virat 50/ Team Ind 150 => 50/150 : 33%)

# %%
virat_df['Innings Player']
# Out:
# 0        E Lewis
# 1        N Pooran
# 2        SO Hetmyer
# 3        RL Chase
# 4        SS Cottrell
# 5        JO Holder
# 6        CH Gayle
# 7        SD Hope
# 8        CR Brathwaite
# 9        KAJ Roach
# 10       O Thomas
# 11       V Kohli
# 12       SS Iyer
# 13       RR Pant
# 14       RG Sharma
# 15       RA Jadeja
# 16       KM Jadhav
# 17       Mohammed Shami
# 18       S Dhawan
# 19       B Kumar
# 44       E Lewis
# 45       SD Hope
# 46       CH Gayle
# 88       AD Mathews
# 89       BKG Mendis
# 90       FDM Karunaratne
# 91       MDKJ Perera
# 92       MD Shanaka
# 93       GSNFG Jayasuriya
# 94       PWH de Silva
# 95       WIA Fernando
# 96       CAK Rajitha
# 97       A Dananjaya
# 99       Soumya Sarkar
# 100      Taijul Islam
# 101      Anamul Haque
# 102      Mushfiqur Rahim
# 103      Mahmudullah
# 104      Mehidy Hasan Miraz
# 105      Sabbir Rahman
# 106      Mohammad Mithun
# 107      Tamim Iqbal
# 108      Rubel Hossain
# 109      Shafiul Islam
# ...

# %%
vdf = virat_df[virat_df['Innings Player'] == 'V Kohli']

# %%
vdf.tail()
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number     Opposition         Ground Innings Date Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  Year
# ...

# %%
sachin_df['Innings Player']
# Out:
# 77610     V Sehwag
# 77611     Yuvraj Singh
# 77612     R Dravid
# 77613     SC Ganguly
# 77614     SR Tendulkar
# 77615     M Kaif
# 77616     MS Dhoni
# 77621     Rajin Saleh
# 77622     Mashrafe Mortaza
# 77623     Mohammad Ashraful
# 77624     Mushfiqur Rahman
# 77625     Khaled Mahmud
# 77626     Nafees Iqbal
# 77627     Khaled Mashud
# 77628     Aftab Ahmed
# 77629     Habibul Bashar
# 77630     Hasibul Hossain
# 77631     Mohammad Rafique
# 77654     SP Fleming
# 77655     MS Sinclair
# 77656     HJH Marshall
# 77657     SB Styris
# 77658     NJ Astle
# 77665     S Sriram
# 77666     M Kaif
# 77667     Joginder Sharma
# 77668     SC Ganguly
# 77669     D Mongia
# 77670     MS Dhoni
# 77671     Z Khan
# 77672     AB Agarkar
# 77673     Yuvraj Singh
# 77674     M Kartik
# 77675     V Sehwag
# 77676     TM Dilshan
# 77677     ST Jayasuriya
# 77678     UDU Chandana
# 77679     KMDN Kulasekara
# 77680     MS Atapattu
# 77681     CRD Fernando
# 77682     DPMD Jayawardene
# ...

# %%
sdf = sachin_df[sachin_df['Innings Player'] == 'SR Tendulkar']

# %%
sdf.tail()
# Out:
#        Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number     Opposition              Ground Innings Date Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  Year
# ...

# %%
sum(vdf['Innings Runs Scored Num']), sum(sdf['Innings Runs Scored Num'])
# Out:
# (11247, 11818)

# %%
len(vdf), len(sdf)
# Out:
# (224, 271)

# %%
sum(vdf['Innings Runs Scored Num'])/len(vdf), sum(sdf['Innings Runs Scored Num'])/len(sdf)
# Out:
# (50.20982142857143, 43.608856088560884)

# %%
100*sum(vdf['Innings Runs Scored Num'])/sum(vdf['Innings Balls Faced']), 100*sum(sdf['Innings Runs Scored Num'])/sum(sdf['Innings Balls Faced'])
# Out:
# (93.56126778138258, 88.21377920429947)

# %%
sum(vdf["100's"]), sum(sdf["100's"])
# Out:
# (42, 37)

# %%
sum(vdf["50's"]), sum(sdf["50's"])
# Out:
# (53, 57)

# %%
sum(vdf['Innings Runs Scored Num'])/ sum(virat_df[virat_df['Country'] == 'India']['Innings Runs Scored Num']), sum(sdf['Innings Runs Scored Num'])/ sum(sachin_df[sachin_df['Country'] == 'India']['Innings Runs Scored Num'])
# Out:
# (0.17610033350556625, 0.16951875493078963)

# %% [markdown]
# ### Visualizations

# %%
virat_df.groupby(['Innings Player'])['Innings Runs Scored Num'].sum().sort_values(ascending=False).head(10).plot(kind = 'bar')
plt.show()

# %%
sachin_df.groupby(['Innings Player'])['Innings Runs Scored Num'].sum().sort_values(ascending=False).head(10).plot(kind = 'bar')
plt.show()

# %%
vdf.groupby(['Year'])['Innings Runs Scored Num'].sum().plot(kind = 'bar')
plt.show()

# %%
sdf.groupby(['Year'])['Innings Runs Scored Num'].sum().plot(kind = 'bar')
plt.show()

# %% [markdown]
# ### Normalizations

# %%
non_virat_df = virat_df[virat_df['Innings Player'] != 'V Kohli']
non_sachin_df = sachin_df[sachin_df['Innings Player'] != 'SR Tendulkar']

# %%
sum(non_virat_df['Innings Runs Scored Num'])/len(non_virat_df)
# Out:
# 24.737756786500366

# %%
(sum(vdf['Innings Runs Scored Num'])/len(vdf)) / (sum(non_virat_df['Innings Runs Scored Num'])/len(non_virat_df))
# Out:
# 2.029683688052565

# %%
sum(non_sachin_df['Innings Runs Scored Num'])/len(non_sachin_df)
# Out:
# 22.43512946754194

# %%
(sum(sdf['Innings Runs Scored Num'])/len(sdf)) / (sum(non_sachin_df['Innings Runs Scored Num'])/len(non_sachin_df))
# Out:
# 1.9437755485945407

# %%
(100*sum(vdf['Innings Runs Scored Num'])/sum(vdf['Innings Balls Faced'])) / (100*sum(non_virat_df['Innings Runs Scored Num'])/sum(non_virat_df['Innings Balls Faced']))
# Out:
# 1.121468839996732

# %%
(100*sum(sdf['Innings Runs Scored Num'])/sum(sdf['Innings Balls Faced'])) / (100*sum(non_sachin_df['Innings Runs Scored Num'])/sum(non_sachin_df['Innings Balls Faced']))
# Out:
# 1.2194651528391862

# %%
sum(vdf["100's"]) / sum(non_virat_df["100's"])
# Out:
# 0.056451612903225805

# %%
sum(sdf["100's"]) / sum(non_sachin_df["100's"])
# Out:
# 0.07991360691144708

# %%
len(vdf) / sum(vdf["100's"]), len(sdf) / sum(sdf["100's"])
# Out:
# (5.333333333333333, 7.324324324324325)

# %%
len(non_virat_df) / sum(non_virat_df["100's"]), len(non_sachin_df) / sum(non_sachin_df["100's"])
# Out:
# (29.311827956989248, 47.377969762419006)

# %%
5.333333333333333 / 29.311827956989248
# Out:
# 0.18195157740278795

# %%
7.324324324324325 / 47.377969762419006
# Out:
# 0.15459346107595562

# %%
sum(vdf["50's"]) / sum(non_virat_df["50's"])
# Out:
# 0.01864883884588318

# %%
sum(sdf["50's"]) / sum(non_sachin_df["50's"])
# Out:
# 0.021664766248574687

# %%
len(vdf) / sum(vdf["50's"]), len(sdf) / sum(sdf["50's"])
# Out:
# (4.226415094339623, 4.754385964912281)

# %%
len(non_virat_df) / sum(non_virat_df["50's"]), len(non_sachin_df) / sum(non_sachin_df["50's"])
# Out:
# (7.673469387755102, 8.33751425313569)

# %%
4.226415094339623 / 7.673469387755102
# Out:
# 0.5507828181453231

# %%
4.754385964912281 / 8.33751425313569
# Out:
# 0.5702402203539483
